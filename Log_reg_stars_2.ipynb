# %%
# Установим библиотеку для работы с датасетами на kaggle
# !pip install opendatasets --quiet

# %%
import opendatasets as od

# Загрузим датасет на прямую с kaggle
dataset_url = 'https://www.kaggle.com/competitions/star-type-classification'

# Upload Kaggle.json file to Colab… (Caution: Do not Share kaggle.json as contains API key of your Kaggle Account)

od.download(dataset_url)
# Out:
# Skipping, found downloaded files in "./star-type-classification" (use force=True to force download)

# %%
import pandas as pd

train = pd.read_csv('/content/star-type-classification/train_star.csv')
test = pd.read_csv('/content/star-type-classification/test_star.csv')
sample_submit = pd.read_csv('/content/star-type-classification/sample_submition_stars.csv')
train
# Out:
#         Vmag    Plx  e_Plx    B-V    SpType       Amag TargetClass
# 0       9.99   7.92   1.61  0.646    G5/G6V  19.483625       Giant
# 1      10.86   3.26   2.12  1.840      M1V:  18.426088       Giant
# 2       8.83   7.57   1.05  0.461       F3V  18.225480       Giant
# 3       7.72  24.80   0.89  0.613      G3IV  19.692257       Giant
# 4       8.81   3.17   1.03  0.872     G6III  16.315296       Dwarf
# ...      ...    ...    ...    ...       ...        ...         ...
# 20727   7.07  14.88   0.90  0.586       F8V  17.933014       Giant
# 20728   9.11   4.71   0.87  0.485       F5V  17.475105       Giant
# 20729   9.69   1.61   1.56  0.384   A2/A3IV  15.724129       Giant
# 20730   8.06  37.33   0.97  0.758       K1V  20.920290       Giant
# 20731   9.20   2.22   0.92  1.031  G8III/IV  15.931765       Giant
#
# [20732 rows x 7 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(3, 3))

sns.countplot(data = train, x = train['TargetClass'], ax=ax, palette='hls')
fig.show()
# Out:
# /tmp/ipython-input-566/3599719307.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = train, x = train['TargetClass'], ax=ax, palette='hls')

# %%
from sklearn.utils import resample

# Разделить данные по классам
df_class_0 = train[train['TargetClass'] == 'Dwarf']
df_class_1 = train[train['TargetClass'] == "Giant"]

# Удалить излишки из класса 1 (мажоритарного)
df_class_1_downsampled = resample(df_class_1,
                                   replace=False,    # без замены
                                   n_samples=len(df_class_0),  # столько же, сколько в классе 0
                                   random_state=42)  # для воспроизводимости

# Объединить данные
train = pd.concat([df_class_0, df_class_1_downsampled])

# Перемешать данные
train= train.sample(frac=1, random_state=42).reset_index(drop=True)

print(f"Баланс классов после андерсэмплинга:")
print(train['TargetClass'].value_counts())
# Out:
# Баланс классов после андерсэмплинга:
# TargetClass
# Giant    4939
# Dwarf    4939
# Name: count, dtype: int64

# %%
train.head(200)
# Out:
#      Vmag    Plx  e_Plx    B-V     SpType       Amag TargetClass
# 0    7.38  22.28   0.72  0.580        G1V  19.119576       Giant
# 1    9.04   2.22   1.49  1.412  K2/K3III:  15.771765       Dwarf
# 2    8.76   2.06   1.93  0.945      G8III  15.329336       Dwarf
# 3    5.56   5.77   0.57  1.637       M3Ib  14.365879       Dwarf
# 4    7.70   6.90   0.90  0.284        A9V  16.894245       Giant
# ..    ...    ...    ...    ...        ...        ...         ...
# 195  7.56   3.23   0.63  1.088   K0III/IV  15.106012       Giant
# 196  8.35   2.04   1.04  0.118    B8/B9II  14.898151       Dwarf
# 197  6.49   6.48   1.01  0.910      G8III  15.547874       Dwarf
# 198  5.74   5.42   0.89  1.528      K5III  14.409996       Dwarf
# 199  9.14  14.22   1.27  0.651     G3/G5V  19.904500       Giant
#
# [200 rows x 7 columns]

# %%
'''
train['SpType'] = train['SpType'].str.replace(':', '', regex=False)
train['SpType'] = train['SpType'].str.replace('+', '', regex=False)
train['SpType'] = train['SpType'].str.replace('...', '', regex=False)
train['SpType'] = train['SpType'].str.replace('..', '', regex=False)
train['SpType'] = train['SpType'].str.replace(',', '/', regex=False)
train['SpType'] = train['SpType'].str.replace('-', '/', regex=False)
train['SpType'] = train['SpType'].str.replace('e', '', regex=False)
train['SpType'] = train['SpType'].str.replace('comp', '', regex=False)
train['SpType'] = train['SpType'].str.replace('np/', '', regex=False)
train['SpType'] = train['SpType'].str.replace('SB', '', regex=False)
#train['SpType'] = train['SpType'].str.split('/')
train.head(400)
'''
# Out:
# "\ntrain['SpType'] = train['SpType'].str.replace(':', '', regex=False)\ntrain['SpType'] = train['SpType'].str.replace('+', '', regex=False)\ntrain['SpType'] = train['SpType'].str.replace('...', '', regex=False)\ntrain['SpType'] = train['SpType'].str.replace('..', '', regex=False)\ntrain['SpType'] = train['SpType'].str.replace(',', '/', regex=False)\ntrain['SpType'] = train['SpType'].str.replace('-', '/', regex=False)\ntrain['SpType'] = train['SpType'].str.replace('e', '', regex=False)\ntrain['SpType'] = train['SpType'].str.replace('comp', '', regex=False)\ntrain['SpType'] = train['SpType'].str.replace('np/', '', regex=False)\ntrain['SpType'] = train['SpType'].str.replace('SB', '', regex=False)\n#train['SpType'] = train['SpType'].str.split('/')\ntrain.head(400)\n"

# %%
import re
import pandas as pd

def clean_sptype(s):
    if pd.isna(s):
        return None

    s = str(s).upper()

    # убираем суффиксы и шум
    s = re.sub(r'[:\?\+\-]', '', s)
    s = re.sub(r'(SB|AB|VAR|E|P|N|AB|A|B)$', '', s)  # только в конце!

    return s

def parse_sptype(s):
    if s is None:
        return pd.Series([None, None, None])

    s = clean_sptype(s)

    # 1) Spectral class (очень важно ^ — только в начале!)
    m1 = re.search(r'^(O|B|A|F|G|K|M|C|N|S|W)', s)
    spec = m1.group(1) if m1 else None

    # 2) Subclass (0–9, 3.5, 5/6)
    m2 = re.search(r'(\d(?:\.\d)?(?:/\d)?)', s)
    subclass = m2.group(1) if m2 else None

    # 3) Luminosity class (сначала длинные!)
    m3 = re.search(r'(III/IV|IV/V|III|II|IV|V|I)', s)
    lum = m3.group(1) if m3 else None

    return pd.Series([spec, subclass, lum])

def normalize_lum(l):
    if l is None:
        return None
    if '/' in l:
        return l.split('/')[-1]   # можно [0], если хочешь Giant bias
    return l

train[['spec_class', 'subclass', 'lum_class']] = train['SpType'].apply(parse_sptype)
train['lum_class_clean'] = train['lum_class'].apply(normalize_lum)


import numpy as np

def fix_subclass(x):
    if pd.isna(x):
        return None

    x = str(x)

    # Если диапазон типа 5/7
    if '/' in x:
        parts = x.split('/')
        try:
            nums = [float(p) for p in parts]
            return np.mean(nums)
        except:
            return None

    # Обычное число
    try:
        return float(x)
    except:
        return None

train['subclass'] = train['subclass'].apply(fix_subclass)

train.head(500)
# Out:
#      Vmag    Plx  e_Plx    B-V     SpType       Amag TargetClass spec_class  \
# 0    7.38  22.28   0.72  0.580        G1V  19.119576       Giant          G
# 1    9.04   2.22   1.49  1.412  K2/K3III:  15.771765       Dwarf          K
# 2    8.76   2.06   1.93  0.945      G8III  15.329336       Dwarf          G
# 3    5.56   5.77   0.57  1.637       M3Ib  14.365879       Dwarf          M
# 4    7.70   6.90   0.90  0.284        A9V  16.894245       Giant          A
# ..    ...    ...    ...    ...        ...        ...         ...        ...
# 495  9.60  12.29   1.53  0.626        G0V  20.047760       Giant          G
# 496  9.40   8.30   1.49  0.608        F7V  18.995390       Giant          F
# 497  9.03   3.53   4.60  0.664        G2V  16.768873       Giant          G
# 498  8.67   4.04   1.10  0.978      G8III  16.701908       Dwarf          G
# 499  8.16  13.84   0.72  0.500        F5V  18.865680       Giant          F
#
#      subclass lum_class lum_class_clean
# 0         1.0         V               V
# 1         2.0       III             III
# 2         8.0       III             III
# 3         3.0         I               I
# 4         9.0         V               V
# ..        ...       ...             ...
# 495       0.0         V               V
# 496       7.0         V               V
# 497       2.0         V               V
# 498       8.0       III             III
# 499       5.0         V               V
#
# [500 rows x 11 columns]

# %%
train = train[train['subclass'].notna()]
# Или эквивалентно: df[~df['subclass'].isna()]

# %%
train.isna().sum()
# Out:
# Vmag               0
# Plx                0
# e_Plx              0
# B-V                0
# SpType             0
# Amag               0
# TargetClass        0
# spec_class         0
# subclass           0
# lum_class          0
# lum_class_clean    0
# dtype: int64

# %%
train.isna().sum()
# Out:
# Vmag               0
# Plx                0
# e_Plx              0
# B-V                0
# SpType             0
# Amag               0
# TargetClass        0
# spec_class         0
# subclass           0
# lum_class          0
# lum_class_clean    0
# dtype: int64

# %%
train = train.drop('SpType',axis = 1)
train = train.drop('lum_class',axis = 1)
train.head(500)
# Out:
#      Vmag    Plx  e_Plx    B-V       Amag TargetClass spec_class  subclass  \
# 0    7.38  22.28   0.72  0.580  19.119576       Giant          G       1.0
# 1    9.04   2.22   1.49  1.412  15.771765       Dwarf          K       2.0
# 2    8.76   2.06   1.93  0.945  15.329336       Dwarf          G       8.0
# 3    5.56   5.77   0.57  1.637  14.365879       Dwarf          M       3.0
# 4    7.70   6.90   0.90  0.284  16.894245       Giant          A       9.0
# ..    ...    ...    ...    ...        ...         ...        ...       ...
# 495  9.60  12.29   1.53  0.626  20.047760       Giant          G       0.0
# 496  9.40   8.30   1.49  0.608  18.995390       Giant          F       7.0
# 497  9.03   3.53   4.60  0.664  16.768873       Giant          G       2.0
# 498  8.67   4.04   1.10  0.978  16.701908       Dwarf          G       8.0
# 499  8.16  13.84   0.72  0.500  18.865680       Giant          F       5.0
#
#     lum_class_clean
# 0                 V
# 1               III
# 2               III
# 3                 I
# 4                 V
# ..              ...
# 495               V
# 496               V
# 497               V
# 498             III
# 499               V
#
# [500 rows x 9 columns]

# %%
train[train['spec_class'].isna()]
# Out:
# Empty DataFrame
# Columns: [Vmag, Plx, e_Plx, B-V, Amag, TargetClass, spec_class, subclass, lum_class_clean]
# Index: []

# %%
# сразу закодируем целевую переменную
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

le.fit(train['TargetClass'])
train['TargetClass'] = le.transform(train['TargetClass'])

train.head()
# Out:
#    Vmag    Plx  e_Plx    B-V       Amag  TargetClass spec_class  subclass  \
# 0  7.38  22.28   0.72  0.580  19.119576            1          G       1.0
# 1  9.04   2.22   1.49  1.412  15.771765            0          K       2.0
# 2  8.76   2.06   1.93  0.945  15.329336            0          G       8.0
# 3  5.56   5.77   0.57  1.637  14.365879            0          M       3.0
# 4  7.70   6.90   0.90  0.284  16.894245            1          A       9.0
#
#   lum_class_clean
# 0               V
# 1             III
# 2             III
# 3               I
# 4               V

# %%
train.head(500)
# Out:
#      Vmag    Plx  e_Plx    B-V       Amag  TargetClass spec_class  subclass  \
# 0    7.38  22.28   0.72  0.580  19.119576            1          G       1.0
# 1    9.04   2.22   1.49  1.412  15.771765            0          K       2.0
# 2    8.76   2.06   1.93  0.945  15.329336            0          G       8.0
# 3    5.56   5.77   0.57  1.637  14.365879            0          M       3.0
# 4    7.70   6.90   0.90  0.284  16.894245            1          A       9.0
# ..    ...    ...    ...    ...        ...          ...        ...       ...
# 495  9.60  12.29   1.53  0.626  20.047760            1          G       0.0
# 496  9.40   8.30   1.49  0.608  18.995390            1          F       7.0
# 497  9.03   3.53   4.60  0.664  16.768873            1          G       2.0
# 498  8.67   4.04   1.10  0.978  16.701908            0          G       8.0
# 499  8.16  13.84   0.72  0.500  18.865680            1          F       5.0
#
#     lum_class_clean
# 0                 V
# 1               III
# 2               III
# 3                 I
# 4                 V
# ..              ...
# 495               V
# 496               V
# 497               V
# 498             III
# 499               V
#
# [500 rows x 9 columns]

# %%
from sklearn.preprocessing import OrdinalEncoder

encoder = OrdinalEncoder(handle_unknown='use_encoded_value',categories = [['O', 'B', 'A', 'F', 'G', 'K', 'M']] ,unknown_value=-1)
encoder.fit(train['spec_class'].values.reshape(-1,1))

encoded = encoder.transform(train['spec_class'].values.reshape(-1,1))
encoded
# Out:
# array([[4.],
#        [5.],
#        [4.],
#        ...,
#        [3.],
#        [6.],
#        [1.]])

# %%
train['spec_class'] = encoded
train
# Out:
#       Vmag    Plx  e_Plx    B-V       Amag  TargetClass  spec_class  subclass  \
# 0     7.38  22.28   0.72  0.580  19.119576            1         4.0       1.0
# 1     9.04   2.22   1.49  1.412  15.771765            0         5.0       2.0
# 2     8.76   2.06   1.93  0.945  15.329336            0         4.0       8.0
# 3     5.56   5.77   0.57  1.637  14.365879            0         6.0       3.0
# 4     7.70   6.90   0.90  0.284  16.894245            1         2.0       9.0
# ...    ...    ...    ...    ...        ...          ...         ...       ...
# 9873  8.54  21.87   1.02  0.667  20.239243            1         4.0       5.0
# 9874  9.57   3.46   1.67  0.397  17.265380            1         3.0       2.0
# 9875  8.43   5.30   1.00  0.426  17.051380            1         3.0       0.0
# 9876  8.71   0.67   1.20  1.601  12.840374            0         6.0       2.0
# 9877  8.92   0.96   1.17  0.055  13.831356            1         1.0       9.0
#
#      lum_class_clean
# 0                  V
# 1                III
# 2                III
# 3                  I
# 4                  V
# ...              ...
# 9873               V
# 9874               V
# 9875               V
# 9876             III
# 9877              IV
#
# [9869 rows x 9 columns]

# %%
encoder2 = OrdinalEncoder(handle_unknown='use_encoded_value',categories=[['I', 'II', 'III', 'IV', 'V']], unknown_value=-1)
encoder2.fit(train['lum_class_clean'].values.reshape(-1,1))

encoded2 = encoder2.transform(train['lum_class_clean'].values.reshape(-1,1))
encoded2
# Out:
# array([[4.],
#        [2.],
#        [2.],
#        ...,
#        [4.],
#        [2.],
#        [3.]])

# %%
train['lum_class_clean'] = encoded2

train.head(500)
# Out:
#      Vmag    Plx  e_Plx    B-V       Amag  TargetClass  spec_class  subclass  \
# 0    7.38  22.28   0.72  0.580  19.119576            1         4.0       1.0
# 1    9.04   2.22   1.49  1.412  15.771765            0         5.0       2.0
# 2    8.76   2.06   1.93  0.945  15.329336            0         4.0       8.0
# 3    5.56   5.77   0.57  1.637  14.365879            0         6.0       3.0
# 4    7.70   6.90   0.90  0.284  16.894245            1         2.0       9.0
# ..    ...    ...    ...    ...        ...          ...         ...       ...
# 495  9.60  12.29   1.53  0.626  20.047760            1         4.0       0.0
# 496  9.40   8.30   1.49  0.608  18.995390            1         3.0       7.0
# 497  9.03   3.53   4.60  0.664  16.768873            1         4.0       2.0
# 498  8.67   4.04   1.10  0.978  16.701908            0         4.0       8.0
# 499  8.16  13.84   0.72  0.500  18.865680            1         3.0       5.0
#
#      lum_class_clean
# 0                4.0
# 1                2.0
# 2                2.0
# 3                0.0
# 4                4.0
# ..               ...
# 495              4.0
# 496              4.0
# 497              4.0
# 498              2.0
# 499              4.0
#
# [500 rows x 9 columns]

# %%
# выделим вектор признаков
X = train.drop(columns=['TargetClass'])
# вектор целевой переменной
y = train['TargetClass']

# %%
X.isna().sum()
# Out:
# Vmag               0
# Plx                0
# e_Plx              0
# B-V                0
# Amag               0
# spec_class         0
# subclass           0
# lum_class_clean    0
# dtype: int64

# %%
#print(X[1260]['subclass'])

# %%
# Проверить типы данных в колонках
print(X.dtypes)

# Найти строки с нечисловыми значениями
for col in X.columns:
    print(f"{col}: {X[col].unique()[:50]}")
# Out:
# Vmag               float64
# Plx                float64
# e_Plx              float64
# B-V                float64
# Amag               float64
# spec_class         float64
# subclass           float64
# lum_class_clean    float64
# dtype: object
# Vmag: [7.38 9.04 8.76 5.56 7.7  9.18 8.25 5.95 8.66 5.01 7.55 7.89 8.27 9.11
#  6.77 8.3  8.18 8.19 7.58 8.05 9.57 8.13 6.71 9.24 9.16 8.47 7.54 7.62
#  5.12 8.17 7.67 6.44 8.2  8.37 7.48 9.6  7.45 8.64 7.94 7.49 8.03 7.72
#  5.59 6.73 8.24 7.66 7.07 5.32 7.52 6.88]
# Plx: [22.28  2.22  2.06  5.77  6.9   2.02 -0.56 79.48  5.73  6.65  2.5   2.36
#   1.86  1.76  5.3   4.97  2.68  2.9   3.84 14.15 22.59  4.36  3.96  1.64
#   7.93  6.54  9.62  1.5   3.25  7.34  1.05  4.63  9.05  2.04  2.08  1.24
#   1.53 13.01  9.16  1.56  5.51 -0.45  1.22  1.54 18.22 37.78  3.55  5.58
#   4.45 21.13]
# e_Plx: [0.72 1.49 1.93 0.57 0.9  0.81 1.07 0.77 1.47 0.78 0.68 0.74 1.69 0.83
#  0.59 0.86 1.16 1.14 0.88 1.   1.24 0.75 0.76 1.17 0.67 0.7  0.97 2.51
#  0.85 0.58 1.3  0.65 1.01 1.55 1.19 0.62 1.2  0.95 0.69 1.29 0.73 0.91
#  0.79 0.82 0.92 1.7  1.23 1.73 0.99 1.15]
# B-V: [ 0.58   1.412  0.945  1.637  0.284  0.113  0.486  0.754  0.397  1.584
#   1.513 -0.1    2.523  1.378  1.352  0.314  0.308  1.647  1.488  0.491
#   0.934  1.003  1.526  1.11   0.501 -0.097  0.905  0.336  1.472  1.115
#   1.122  1.059  0.127  1.074  1.016  1.238  0.042  1.     0.534  0.673
#   1.661  0.847  1.943 -0.131  1.198  0.62   0.445  1.508  1.203  1.123]
# Amag: [19.119576  15.771765  15.329336  14.365879  16.894245  15.706757
#  11.99094   20.45129   17.450773  14.124108  14.5397005 14.7545595
#  14.617565  15.3375635 15.391378  16.78178   15.320675  15.501989
#  15.501657  18.803783  21.33958   16.327433  14.698477  15.3142185
#  18.656364  14.54422   16.967888  17.455875  13.500456  15.859417
#  14.448481  13.275947  15.997905  16.223244  14.748151  14.720316
#  13.737109  14.293457  18.051386  19.409477  13.415623  17.345758
#  11.206062  12.921799  13.967604  19.022741  18.47631   14.481142
#  16.973171  15.9018   ]
# spec_class: [ 4.  5.  6.  2.  1.  3. -1.  0.]
# subclass: [1.  2.  8.  3.  9.  0.  4.  5.  6.  7.  9.5 0.5 2.5 1.5 4.5 7.7 8.5 6.5
#  3.5 7.5 5.5 6.2 0.7 4.2]
# lum_class_clean: [4. 2. 0. 1. 3.]

# %%
X['subclass'] = pd.to_numeric(X['subclass'], errors='coerce')

# %%
X.isna().sum()
# Out:
# Vmag               0
# Plx                0
# e_Plx              0
# B-V                0
# Amag               0
# spec_class         0
# subclass           0
# lum_class_clean    0
# dtype: int64

# %%
# Найти строки, где возникли NaN
mask = X['subclass'].isna()
problem_rows = X[mask]
#print(problem_rows['subclass_original'])  # если сохранили оригинал

# Или найти уникальные значения, которые не преобразовались
print(X[X['subclass'].isna()].index)


# Посмотреть оригинальные значения в проблемных строках
print(X.loc[X['subclass'].isna(), 'subclass'].unique())

# Или посмотреть полные строки
print(X[X['subclass'].isna()]['subclass'])
# Out:
# Index([], dtype='int64')
# []
# Series([], Name: subclass, dtype: float64)

# %%
print(X.shape)
print(y.shape)
# Out:
# (9869, 8)
# (9869,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

print(f'Train dataset size: {X_train.shape}, {y_train.shape}')
print(f'Train dataset size: {X_test.shape}, {y_test.shape}')
# Out:
# Train dataset size: (6908, 8), (6908,)
# Train dataset size: (2961, 8), (2961,)

# %%
X_train.isna().sum()
# Out:
# Vmag               0
# Plx                0
# e_Plx              0
# B-V                0
# Amag               0
# spec_class         0
# subclass           0
# lum_class_clean    0
# dtype: int64

# %%
# Проверить типы данных в колонках
print(X_train.dtypes)

# Найти строки с нечисловыми значениями
for col in X_train.columns:
    print(f"{col}: {X_train[col].unique()[:10]}")
# Out:
# Vmag               float64
# Plx                float64
# e_Plx              float64
# B-V                float64
# Amag               float64
# spec_class         float64
# subclass           float64
# lum_class_clean    float64
# dtype: object
# Vmag: [ 6.86  9.57  9.79  6.48  8.91  9.62  9.59 10.18  5.65  7.25]
# Plx: [ 3.76  2.72  6.07  3.2  11.48 -0.29  7.52  8.27 -3.17  1.88]
# e_Plx: [0.64 1.35 2.24 1.23 0.83 1.22 1.5  1.43 3.58 0.52]
# B-V: [1.376 0.474 0.394 0.09  1.603 0.659 0.562 0.105 1.273 1.014]
# Amag: [14.735939 16.742844 18.705944 17.31575  16.779709 11.22199  19.00109
#  19.177528 17.685297 12.02079 ]
# spec_class: [ 5.  3.  1.  2.  4.  6. -1.  0.]
# subclass: [3.  2.  9.  1.  5.  9.5 8.  0.  6.  4. ]
# lum_class_clean: [2. 4. 0. 1. 3.]

# %%
X_train.isna().sum()
# Out:
# Vmag               0
# Plx                0
# e_Plx              0
# B-V                0
# Amag               0
# spec_class         0
# subclass           0
# lum_class_clean    0
# dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

std = StandardScaler()

std.fit(X_train) # train.csv

X_train_std = std.transform(X_train) # train.csv
X_train_std = pd.DataFrame(X_train_std, columns=X.columns)

X_test_std = std.transform(X_test) # test.csv
X_test_std = pd.DataFrame(X_test_std, columns=X.columns)

# %%
X_train_std.isna().sum()
# Out:
# Vmag               0
# Plx                0
# e_Plx              0
# B-V                0
# Amag               0
# spec_class         0
# subclass           0
# lum_class_clean    0
# dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

# Создадим модель дерева решений
log_reg = LogisticRegression()

# обучение модели
log_reg.fit(X_train_std, y_train)

# предсказание ответов для тестовой выборки
y_pred = log_reg.predict(X_test_std)

# %%
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

conf_matrix = confusion_matrix(y_test, y_pred)

fig, ax = plt.subplots(figsize=(8,6), dpi=100)

display = ConfusionMatrixDisplay(conf_matrix, display_labels=log_reg.classes_)

display.plot(ax=ax)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# y_pred - ответы которые вернула модель для X_test
# y_test - это правильные ответы для X_test
print(f'Accuracy: {accuracy_score(y_test, y_pred)}')
print(f'Precision: {precision_score(y_test, y_pred)}')
print(f'Recall: {recall_score(y_test, y_pred)}')
print(f'F1-score: {f1_score(y_test, y_pred)}')
# Out:
# Accuracy: 0.993920972644377
# Precision: 1.0
# Recall: 0.9879839786381842
# F1-score: 0.9939556749496307

# %%
X_std = std.transform(X) # train.csv
X_std = pd.DataFrame(X_std,  columns=X_train.columns)

# %%
print(X.shape)
print(X_std.shape)
print(y.shape)
# Out:
# (9869, 8)
# (9869, 8)
# (9869,)

# %%
from sklearn.linear_model import LogisticRegression

# Создадим модель логистической регрессии
log_reg2 = LogisticRegression()

# обучение модели
log_reg2.fit(X_std, y)
# Out:
# LogisticRegression()

# %%
y_pred2 = log_reg2.predict(X_std)

from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

conf_matrix = confusion_matrix(y, y_pred2)

fig, ax = plt.subplots(figsize=(8,6), dpi=100)

display = ConfusionMatrixDisplay(conf_matrix, display_labels=log_reg.classes_)

display.plot(ax=ax)

print(f'Accuracy: {accuracy_score(y, y_pred2)}')
print(f'Precision: {precision_score(y, y_pred2)}')
print(f'Recall: {recall_score(y, y_pred2)}')
print(f'F1-score: {f1_score(y, y_pred2)}')
# Out:
# Accuracy: 0.9952376127267201
# Precision: 0.9997955428337764
# Recall: 0.9906807131280388
# F1-score: 0.9952172585733184

# %%
import re
import pandas as pd

def clean_sptype(s):
    if pd.isna(s):
        return None

    s = str(s).upper()

    # убираем суффиксы и шум
    s = re.sub(r'[:\?\+\-]', '', s)
    s = re.sub(r'(SB|AB|VAR|E|P|N|AB|A|B)$', '', s)  # только в конце!

    return s

def parse_sptype(s):
    if s is None:
        return pd.Series([None, None, None])

    s = clean_sptype(s)

    # 1) Spectral class (очень важно ^ — только в начале!)
    m1 = re.search(r'^(O|B|A|F|G|K|M|C|N|S|W)', s)
    spec = m1.group(1) if m1 else None

    # 2) Subclass (0–9, 3.5, 5/6)
    m2 = re.search(r'(\d(?:\.\d)?(?:/\d)?)', s)
    subclass = m2.group(1) if m2 else None

    # 3) Luminosity class (сначала длинные!)
    m3 = re.search(r'(III/IV|IV/V|III|II|IV|V|I)', s)
    lum = m3.group(1) if m3 else None

    return pd.Series([spec, subclass, lum])

def normalize_lum(l):
    if l is None:
        return None
    if '/' in l:
        return l.split('/')[-1]   # можно [0], если хочешь Giant bias
    return l

test[['spec_class', 'subclass', 'lum_class']] = test['SpType'].apply(parse_sptype)
test['lum_class_clean'] = test['lum_class'].apply(normalize_lum)


import numpy as np

def fix_subclass(x):
    if pd.isna(x):
        return None

    x = str(x)

    # Если диапазон типа 5/7
    if '/' in x:
        parts = x.split('/')
        try:
            nums = [float(p) for p in parts]
            return np.mean(nums)
        except:
            return None

    # Обычное число
    try:
        return float(x)
    except:
        return None

test['subclass'] = test['subclass'].apply(fix_subclass)

train.head(500)
# Out:
#      Vmag    Plx  e_Plx    B-V       Amag  TargetClass  spec_class  subclass  \
# 0    7.38  22.28   0.72  0.580  19.119576            1         4.0       1.0
# 1    9.04   2.22   1.49  1.412  15.771765            0         5.0       2.0
# 2    8.76   2.06   1.93  0.945  15.329336            0         4.0       8.0
# 3    5.56   5.77   0.57  1.637  14.365879            0         6.0       3.0
# 4    7.70   6.90   0.90  0.284  16.894245            1         2.0       9.0
# ..    ...    ...    ...    ...        ...          ...         ...       ...
# 495  9.60  12.29   1.53  0.626  20.047760            1         4.0       0.0
# 496  9.40   8.30   1.49  0.608  18.995390            1         3.0       7.0
# 497  9.03   3.53   4.60  0.664  16.768873            1         4.0       2.0
# 498  8.67   4.04   1.10  0.978  16.701908            0         4.0       8.0
# 499  8.16  13.84   0.72  0.500  18.865680            1         3.0       5.0
#
#      lum_class_clean
# 0                4.0
# 1                2.0
# 2                2.0
# 3                0.0
# 4                4.0
# ..               ...
# 495              4.0
# 496              4.0
# 497              4.0
# 498              2.0
# 499              4.0
#
# [500 rows x 9 columns]

# %%
test = test.fillna(1)
test.isna().sum()
# Out:
# Vmag               0
# Plx                0
# e_Plx              0
# B-V                0
# SpType             0
# Amag               0
# spec_class         0
# subclass           0
# lum_class          0
# lum_class_clean    0
# dtype: int64

# %%
test
# Out:
#        Vmag   Plx  e_Plx    B-V    SpType       Amag spec_class  subclass  \
# 0      7.91  6.33   1.01  0.843     G5III  16.917019          G       5.0
# 1      7.35  1.30   0.53  1.304  K1/K2III  12.919716          K       1.0
# 2      6.75  8.01   0.84  1.019     K1III  16.268162          K       1.0
# 3      4.47  7.03   0.72  1.283     K4III  13.704777          K       4.0
# 4      7.33  2.45   1.14  1.600     K5III  14.275830          K       5.0
# ...     ...   ...    ...    ...       ...        ...        ...       ...
# 18815  7.72  2.41   1.05  1.487     K4III  14.630085          K       4.0
# 18816  8.27  1.98   0.81  1.005     K0III  14.753326          K       0.0
# 18817  8.53  1.14   0.89 -0.093  B7/B8III  13.814524          B       7.0
# 18818  9.09  6.41   1.10  0.480       F6V  18.124290          F       6.0
# 18819  8.74  2.44   0.79  1.256     M7III  15.676949          M       7.0
#
#       lum_class lum_class_clean
# 0           III             III
# 1           III             III
# 2           III             III
# 3           III             III
# 4           III             III
# ...         ...             ...
# 18815       III             III
# 18816       III             III
# 18817       III             III
# 18818         V               V
# 18819       III             III
#
# [18820 rows x 10 columns]

# %%
test = test.drop('SpType',axis = 1)
test = test.drop('lum_class',axis = 1)
encoded3 = encoder.transform(test['spec_class'].values.reshape(-1,1))
test['spec_class'] = encoded3

encoded4 = encoder2.transform(test['lum_class_clean'].values.reshape(-1,1))
test['lum_class_clean'] = encoded4


test_std = std.transform(test) # test.csv
test_std = pd.DataFrame(test_std, columns=X.columns)





y_last = log_reg2.predict(test_std)

# %%
sample_submit['TargetClass'] = y_last

sample_submit.to_csv('my_submit_stars_std.csv', index=False)
